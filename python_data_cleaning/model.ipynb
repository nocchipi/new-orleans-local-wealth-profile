# %%
import arviz as az
import pandas as pd
import polars as pl
import polars.selectors as cs
import numpy as np
import matplotlib.pyplot as plt
import os
import bambi as bmb

# %%
OUTPUT_PATH  = os.getenv("OUTPUT_PATH")
SIPP_MODEL_DATA = "sipp_model.parquet"

# %%
sipp_model = pl.read_parquet(os.path.join(OUTPUT_PATH,SIPP_MODEL_DATA))
sipp_model
# Out:
# shape: (26_173, 269)
# ┌────────┬───────┬───────┬───────────┬───┬─────────────┬──────────────┬─────────────┬──────────────┐
# │ row_id ┆ state ┆ metro ┆ hh_income ┆ … ┆ REPWGT240   ┆ prank_assets ┆ prank_debts ┆ prank_networ │
# │ ---    ┆ ---   ┆ ---   ┆ ---       ┆   ┆ ---         ┆ ---          ┆ ---         ┆ th           │
# │ u32    ┆ i64   ┆ i8    ┆ i32       ┆   ┆ f64         ┆ f64          ┆ f64         ┆ ---          │
# │        ┆       ┆       ┆           ┆   ┆             ┆              ┆             ┆ f64          │
# ╞════════╪═══════╪═══════╪═══════════╪═══╪═════════════╪══════════════╪═════════════╪══════════════╡
# │ 0      ┆ 20    ┆ 1     ┆ 5         ┆ … ┆ 2879.528162 ┆ null         ┆ null        ┆ null         │
# │ 1      ┆ 20    ┆ 1     ┆ 8         ┆ … ┆ 2129.511725 ┆ 0.377196     ┆ 0.531261    ┆ 0.348163     │
# │ 2      ┆ 20    ┆ 1     ┆ 12        ┆ … ┆ 6463.823387 ┆ 0.403515     ┆ null        ┆ 0.523844     │
# │ 3      ┆ 20    ┆ 1     ┆ 10        ┆ … ┆ 2472.555624 ┆ 0.440057     ┆ 0.418817    ┆ 0.51375      │
# │ 4      ┆ 20    ┆ 1     ┆ 12        ┆ … ┆ 1584.773742 ┆ 0.971645     ┆ null        ┆ 0.974242     │
# │ …      ┆ …     ┆ …     ┆ …         ┆ … ┆ …           ┆ …            ┆ …           ┆ …            │
# │ 26168  ┆ 6     ┆ 1     ┆ 13        ┆ … ┆ 5410.960008 ┆ 0.899592     ┆ 0.94309     ┆ 0.870182     │
# │ 26169  ┆ 6     ┆ 1     ┆ 7         ┆ … ┆ 5291.143187 ┆ 0.638027     ┆ null        ┆ 0.719828     │
# │ 26170  ┆ 6     ┆ 1     ┆ 12        ┆ … ┆ 1643.249597 ┆ 0.793583     ┆ 0.93272     ┆ 0.680865     │
# │ 26171  ┆ 6     ┆ 1     ┆ 9         ┆ … ┆ 4842.080048 ┆ 0.813637     ┆ 0.01584     ┆ 0.84836      │
# │ 26172  ┆ 6     ┆ 1     ┆ 14        ┆ … ┆ 1838.971379 ┆ 0.901425     ┆ 0.97859     ┆ 0.830374     │
# └────────┴───────┴───────┴───────────┴───┴─────────────┴──────────────┴─────────────┴──────────────┘

# %%
sipp_model = (sipp_model
 .with_columns(
     pl.concat_str([pl.col("race_eth"),pl.col("state")],separator=":").alias('race_eth_state'),
     pl.concat_str([pl.col("race_eth"),pl.col("edu")],separator=":").alias('race_eth_edu'),
     pl.concat_str([pl.col("race_eth"),pl.col("age")],separator=":").alias('race_eth_age'),
     pl.concat_str([pl.col("race_eth"),pl.col("hh_income")],separator=":").alias('race_eth_income'),
 )
)

# %% [markdown]
# # Models

# %% [markdown]
# ## Any Asset Model

# %%
any_asset_model_cols = ['hh_any_asset',
'state',
'hh_income',
'age',
'race_eth',
'edu',
'tenure',
'household_type',
'male',
'metro',
'disability',
'class_worker',
'public_assistance',
'social_security',
'poverty',
'citizen']

# %%
any_asset_model_df = sipp_model.select(pl.col(any_asset_model_cols)).to_pandas().dropna(subset=any_asset_model_cols)
any_asset_model_df

# %%
any_asset_model_df.describe()

# %%
for col in ['state','hh_income','age','race_eth','edu','tenure','household_type','class_worker']:
    any_asset_model_df[col] = any_asset_model_df[col].astype('category')

# %%
any_asset_model_df.info()

# %%
# change tenure from random effect to fixed effect
any_asset_model_formula = """
hh_any_asset ~ male + metro + disability + class_worker + public_assistance + social_security +
poverty + citizen + tenure + (1|state) + (1|hh_income) + (1|age) + (1 | race_eth) + 
(1 | edu) + (1|household_type)
"""

# %%
any_asset_priors = {
    "Intercept": bmb.Prior("Normal", mu=0, sigma=2.5),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "group_specific": bmb.Prior(
        "Normal",
        mu=0,
        sigma=bmb.Prior("Exponential", lam=1),
    )
}

# %%
any_asset_model = bmb.Model(formula=any_asset_model_formula, 
                            data=any_asset_model_df, 
                            family="bernoulli",
                            priors=any_asset_priors,
                            noncentered=True)

# %%
any_asset_model_idata = any_asset_model.fit(draws=1000,
                                            tune=1500,
                                            chains=4,
                                            target_accept=0.98, 
                                            sampler_kwargs={"max_treedepth":15})

# %%
az.to_netcdf(any_asset_model_idata,r'models/any_asset_model_run2_20260214.nc')

# %%
any_asset_model_summ = az.summary(any_asset_model_idata, var_names=["Intercept", "male", "metro", "disability", "poverty","citizen"], round_to=3)
any_asset_model_summ[["mean","sd","hdi_3%","hdi_97%","r_hat","ess_bulk","ess_tail"]]

# %%
post_vars = list(any_asset_model_idata.posterior.data_vars)
sd_like = [v for v in post_vars if ("sigma" in v.lower()) or ("sd" in v.lower())]
summ_sd = az.summary(any_asset_model_idata, var_names=sd_like, round_to=3)
summ_sd

# %%
any_asset_model_df.groupby("tenure",observed=False)["hh_any_asset"].mean()

# %%
any_asset_model_df.groupby("tenure",observed=False)["hh_any_asset"].count()

# %%
az.plot_trace(
    any_asset_model_idata,
    var_names=["Intercept", "male", "metro", "1|hh_income_sigma"],
)

# %%
az.plot_posterior(
    any_asset_model_idata,
    var_names=["metro", "male", "citizen"],
    hdi_prob=0.95
)

# %%
az.plot_forest(
    any_asset_model_idata,
    var_names=["1|state_sigma",
               "1|hh_income_sigma",
               "1|age_sigma",
               "1|race_eth_sigma",
               "1|edu_sigma",
               "1|household_type_sigma"],
    combined=True,
)

# %% [markdown]
# ## Any Debt Model

# %%
any_debt_model_cols = ['hh_any_debt',
'state',
'hh_income',
'age',
'race_eth',
'edu',
'tenure',
'household_type',
'male',
'metro',
'disability',
'class_worker',
'public_assistance',
'social_security',
'poverty',
'citizen']

# %%
any_debt_model_df = sipp_model.select(pl.col(any_debt_model_cols)).to_pandas().dropna(subset=any_debt_model_cols)
any_debt_model_df

# %%
any_debt_model_df.describe()

# %% [markdown]
# ## Percent Rank Asset Model

# %%
pr_asset_model_cols = ['prank_assets',
'state',
'hh_income',
'age',
'race_eth',
'edu',
'tenure',
'household_type',
'male',
'metro',
'disability',
'class_worker',
'public_assistance',
'social_security',
'poverty',
'citizen',
'english_at_home',
'homevalue',
'race_eth_state',	
'race_eth_edu',	
'race_eth_age',	
'race_eth_income']

# %%
pr_asset_model_df = sipp_model.select(pl.col(pr_asset_model_cols)).to_pandas().dropna(subset=pr_asset_model_cols)
pr_asset_model_df
# Out:
#        prank_assets  state  hh_income  age  race_eth  edu  tenure  \
# 1          0.377196     20          8    5         1    3       2
# 2          0.403515     20         12    8         1    1       1
# 3          0.440057     20         10   11         1    2       2
# 4          0.971645     20         12   11         1    5       1
# 5          0.057291     20          3   11         5    1       3
# ...             ...    ...        ...  ...       ...  ...     ...
# 26168      0.899592      6         13    9         3    1       2
# 26169      0.638027      6          7   11         4    3       1
# 26170      0.793583      6         12    7         4    3       2
# 26171      0.813637      6          9    9         4    1       1
# 26172      0.901425      6         14    8         3    2       3
#
#        household_type  male  metro  ...  public_assistance  social_security  \
# 1                   4     0      1  ...                  0                0
# 2                   1     0      1  ...                  0                0
# 3                   2     0      1  ...                  0                1
# 4                   2     1      1  ...                  0                1
# 5                   4     1      1  ...                  1                0
# ...               ...   ...    ...  ...                ...              ...
# 26168               2     1      1  ...                  0                0
# 26169               2     1      1  ...                  0                1
# 26170               1     1      1  ...                  0                1
# 26171               2     1      1  ...                  0                1
# 26172               1     1      1  ...                  1                1
#
#        poverty  citizen  english_at_home  homevalue  race_eth_state  \
# 1            0        1                1          4            1:20
# 2            0        1                0          4            1:20
# 3            0        1                1          3            1:20
# 4            0        1                1          4            1:20
# 5            1        1                1          1            5:20
# ...        ...      ...              ...        ...             ...
# 26168        0        1                0          6             3:6
# 26169        0        1                1          5             4:6
# 26170        0        1                0          6             4:6
# 26171        0        1                0          6             4:6
# 26172        0        1                0          1             3:6
#
#        race_eth_edu race_eth_age race_eth_income
# 1               1:3          1:5             1:8
# 2               1:1          1:8            1:12
# 3               1:2         1:11            1:10
# 4               1:5         1:11            1:12
# 5               5:1         5:11             5:3
# ...             ...          ...             ...
# 26168           3:1          3:9            3:13
# 26169           4:3         4:11             4:7
# 26170           4:3          4:7            4:12
# 26171           4:1          4:9             4:9
# 26172           3:2          3:8            3:14
#
# [23245 rows x 22 columns]

# %%
pr_asset_model_df.describe()
# Out:
#        prank_assets         state     hh_income           age      race_eth  \
# count  23245.000000  23245.000000  23245.000000  23245.000000  23245.000000
# mean       0.497144     27.961884      9.743386      8.365197      1.627963
# std        0.285066     16.254010      4.526943      3.473372      1.048978
# min        0.000025      1.000000      1.000000      2.000000      1.000000
# 25%        0.256295     12.000000      6.000000      6.000000      1.000000
# 50%        0.493172     28.000000     10.000000      9.000000      1.000000
# 75%        0.740917     42.000000     13.000000     11.000000      2.000000
# max        0.999942     56.000000     18.000000     15.000000      5.000000
#
#                 edu        tenure  household_type          male         metro  \
# count  23245.000000  23245.000000    23245.000000  23245.000000  23245.000000
# mean       3.013250      2.081437        2.716369      0.490213      0.827232
# std        1.189749      0.772328        1.183714      0.499915      0.378055
# min        1.000000      1.000000        1.000000      0.000000      0.000000
# 25%        2.000000      1.000000        2.000000      0.000000      1.000000
# 50%        3.000000      2.000000        3.000000      0.000000      1.000000
# 75%        4.000000      3.000000        4.000000      1.000000      1.000000
# max        5.000000      3.000000        4.000000      1.000000      1.000000
#
#          disability  class_worker  public_assistance  social_security  \
# count  23245.000000  23245.000000       23245.000000     23245.000000
# mean       0.272575      3.475801           0.061734         0.357625
# std        0.445293      0.937829           0.240676         0.479311
# min        0.000000      1.000000           0.000000         0.000000
# 25%        0.000000      3.000000           0.000000         0.000000
# 50%        0.000000      3.000000           0.000000         0.000000
# 75%        1.000000      4.000000           0.000000         1.000000
# max        1.000000      5.000000           1.000000         1.000000
#
#             poverty       citizen  english_at_home     homevalue
# count  23245.000000  23245.000000     23245.000000  23245.000000
# mean       0.135556      0.942697         0.881824      3.126135
# std        0.342324      0.232425         0.322823      1.850390
# min        0.000000      0.000000         0.000000      1.000000
# 25%        0.000000      1.000000         1.000000      1.000000
# 50%        0.000000      1.000000         1.000000      4.000000
# 75%        0.000000      1.000000         1.000000      4.000000
# max        1.000000      1.000000         1.000000      8.000000

# %%
for col in ['state','hh_income','age','race_eth','edu','tenure',
            'household_type','class_worker','homevalue','race_eth_state',
            'race_eth_edu',	'race_eth_age',	'race_eth_income']:
    pr_asset_model_df[col] = pr_asset_model_df[col].astype('category')

# %%
pr_asset_model_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23245 entries, 1 to 26172
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   prank_assets       23245 non-null  float64
#  1   state              23245 non-null  category
#  2   hh_income          23245 non-null  category
#  3   age                23245 non-null  category
#  4   race_eth           23245 non-null  category
#  5   edu                23245 non-null  category
#  6   tenure             23245 non-null  category
#  7   household_type     23245 non-null  category
#  8   male               23245 non-null  int32
#  9   metro              23245 non-null  int8
#  10  disability         23245 non-null  int32
#  11  class_worker       23245 non-null  category
#  12  public_assistance  23245 non-null  int8
#  13  social_security    23245 non-null  int8
#  14  poverty            23245 non-null  int8
#  15  citizen            23245 non-null  int32
#  16  english_at_home    23245 non-null  int32
#  17  homevalue          23245 non-null  category
#  18  race_eth_state     23245 non-null  category
#  19  race_eth_edu       23245 non-null  category
#  20  race_eth_age       23245 non-null  category
#  21  race_eth_income    23245 non-null  category
# dtypes: category(13), float64(1), int32(4), int8(4)
# memory usage: 1.1 MB

# %%
# change tenure from random effect to fixed effect
pr_asset_model_formula = """
prank_assets ~ male + metro + disability + class_worker + public_assistance
            + social_security + poverty + citizen + english_at_home + homevalue
            + tenure
            + (1|state) + (1|hh_income) + (1|age) + (1|race_eth) + (1|edu)
            + (1|household_type)
            + (1|race_eth:state) + (1|race_eth:edu) + (1|race_eth:age) + (1|race_eth:hh_income)
"""

# %%
pr_asset_priors = {
    "Intercept": bmb.Prior("Normal", mu=0, sigma=2.5),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "group_specific": bmb.Prior(
        "Normal",
        mu=0,
        sigma=bmb.Prior("Exponential", lam=1),
    )
}

# %%
pr_asset_model = bmb.Model(formula=pr_asset_model_formula, 
                            data=pr_asset_model_df, 
                            family="beta",
                            link='logit',
                            priors=pr_asset_priors,
                            noncentered=True)

# %%
pr_asset_model_idata = pr_asset_model.fit(draws=2500,
                                          tune=2500,
                                          chains=4,
                                          target_accept=0.99)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# c:\Users\nicho\.conda\envs\no-lwp\Lib\site-packages\pytensor\link\c\cmodule.py:2986: UserWarning: PyTensor could not link to a BLAS installation. Operations that might benefit from BLAS will be severely degraded.
# This usually happens when PyTensor is installed via pip. We recommend it be installed via conda/mamba/pixi instead.
# Alternatively, you can use an experimental backend such as Numba or JAX that perform their own BLAS optimizations, by setting `pytensor.config.mode == 'NUMBA'` or passing `mode='NUMBA'` when compiling a PyTensor function.
# For more options and details see https://pytensor.readthedocs.io/en/latest/troubleshooting.html#how-do-i-configure-test-my-blas-library
#   warnings.warn(
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [kappa, Intercept, male, metro, disability, class_worker, public_assistance, social_security, poverty, citizen, english_at_home, homevalue, tenure, 1|state_sigma, 1|state_offset, 1|hh_income_sigma, 1|hh_income_offset, 1|age_sigma, 1|age_offset, 1|race_eth_sigma, 1|race_eth_offset, 1|edu_sigma, 1|edu_offset, 1|household_type_sigma, 1|household_type_offset, 1|race_eth:state_sigma, 1|race_eth:state_offset, 1|race_eth:edu_sigma, 1|race_eth:edu_offset, 1|race_eth:age_sigma, 1|race_eth:age_offset, 1|race_eth:hh_income_sigma, 1|race_eth:hh_income_offset]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_500 tune and 2_500 draw iterations (10_000 + 10_000 draws total) took 27559 seconds.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.

# %%
az.to_netcdf(pr_asset_model_idata,r'models/pr_asset_model_20260215.nc')
# Out:
# 'models/pr_asset_model_20260215.nc'

# %%
pr_asset_model_summ = az.summary(pr_asset_model_idata, var_names=["Intercept", "male", "metro","disability",'class_worker','public_assistance',
                                                                  'social_security',"poverty","citizen",'english_at_home','homevalue',
                                                                  'tenure'], round_to=3)
pr_asset_model_summ[["mean","sd","hdi_3%","hdi_97%","r_hat","ess_bulk","ess_tail"]]
# Out:
#                     mean     sd  hdi_3%  hdi_97%  r_hat   ess_bulk  ess_tail
# Intercept          1.016  0.436   0.210    1.861  1.002   1201.868  2749.748
# male               0.037  0.010   0.019    0.055  1.001  14092.364  7367.431
# metro              0.011  0.013  -0.013    0.036  1.000  13437.341  7781.099
# disability        -0.122  0.012  -0.145   -0.099  1.000  13606.459  6803.935
# class_worker[2.0] -0.255  0.036  -0.321   -0.187  1.001   4368.499  6469.629
# class_worker[3.0] -0.591  0.030  -0.649   -0.536  1.001   3835.400  5461.145
# class_worker[4.0] -0.418  0.036  -0.486   -0.350  1.001   4447.815  6431.124
# class_worker[5.0] -0.510  0.032  -0.570   -0.450  1.000   3958.293  5891.459
# public_assistance -0.296  0.021  -0.334   -0.257  1.000  12170.254  7719.385
# social_security   -0.053  0.016  -0.085   -0.024  1.001  14976.101  6589.572
# poverty            0.052  0.021   0.011    0.091  1.000   9998.606  7385.039
# citizen            0.068  0.024   0.024    0.113  1.000  11759.072  8084.062
# english_at_home    0.029  0.018  -0.006    0.061  1.000  11495.696  7486.135
# homevalue[2]      -0.951  0.362  -1.658   -0.299  1.002   1325.454  2176.545
# homevalue[3]      -0.504  0.361  -1.188    0.169  1.002   1315.096  2179.752
# homevalue[4]      -0.089  0.361  -0.784    0.574  1.002   1319.862  2192.532
# homevalue[5]       0.368  0.361  -0.312    1.045  1.002   1324.388  2233.410
# homevalue[6]       0.667  0.362   0.017    1.377  1.002   1330.254  2295.166
# homevalue[7]       0.849  0.363   0.158    1.515  1.002   1344.196  2373.919
# homevalue[8]       1.316  0.363   0.655    2.019  1.002   1317.391  2192.702
# tenure[2]         -0.250  0.013  -0.274   -0.226  1.000  13965.118  7338.832
# tenure[3]         -1.594  0.361  -2.290   -0.936  1.002   1323.836  2181.975

# %%
post_vars = list(pr_asset_model_idata.posterior.data_vars)
sd_like = [v for v in post_vars if ("sigma" in v.lower()) or ("sd" in v.lower())]
summ_sd = az.summary(pr_asset_model_idata, var_names=sd_like, round_to=3)
summ_sd
# Out:
#                              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# 1|state_sigma               0.045  0.013   0.019    0.070      0.000    0.000
# 1|hh_income_sigma           0.532  0.102   0.359    0.719      0.002    0.002
# 1|age_sigma                 0.177  0.045   0.105    0.259      0.001    0.001
# 1|race_eth_sigma            0.144  0.094   0.042    0.283      0.002    0.005
# 1|edu_sigma                 0.275  0.147   0.097    0.513      0.003    0.005
# 1|household_type_sigma      0.130  0.113   0.031    0.296      0.002    0.006
# 1|race_eth:state_sigma      0.048  0.013   0.024    0.074      0.000    0.000
# 1|race_eth:edu_sigma        0.037  0.014   0.013    0.063      0.000    0.000
# 1|race_eth:age_sigma        0.062  0.011   0.042    0.083      0.000    0.000
# 1|race_eth:hh_income_sigma  0.013  0.010   0.000    0.030      0.000    0.000
#
#                             ess_bulk  ess_tail  r_hat
# 1|state_sigma               1056.350   936.112  1.003
# 1|hh_income_sigma           1639.155  3066.318  1.004
# 1|age_sigma                 2109.639  4105.506  1.003
# 1|race_eth_sigma            3340.729  5094.557  1.001
# 1|edu_sigma                 3134.436  4607.732  1.002
# 1|household_type_sigma      3124.832  4404.541  1.000
# 1|race_eth:state_sigma      1044.682  1487.418  1.001
# 1|race_eth:edu_sigma        3485.618  3678.592  1.001
# 1|race_eth:age_sigma        4054.563  5880.779  1.000
# 1|race_eth:hh_income_sigma  3410.975  4108.460  1.000

# %%
az.plot_trace(
    pr_asset_model_idata,
    var_names=["Intercept", "male", "metro", "1|hh_income_sigma"],
)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'Intercept'}>],
#        [<Axes: title={'center': 'male'}>,
#         <Axes: title={'center': 'male'}>],
#        [<Axes: title={'center': 'metro'}>,
#         <Axes: title={'center': 'metro'}>],
#        [<Axes: title={'center': '1|hh_income_sigma'}>,
#         <Axes: title={'center': '1|hh_income_sigma'}>]], dtype=object)

# %%
az.plot_posterior(
    pr_asset_model_idata,
    var_names=["metro", "male", "citizen"],
    hdi_prob=0.95
)
# Out:
# array([<Axes: title={'center': 'metro'}>,
#        <Axes: title={'center': 'male'}>,
#        <Axes: title={'center': 'citizen'}>], dtype=object)

# %%
az.plot_forest(
    pr_asset_model_idata,
    var_names=["1|state_sigma",
               "1|hh_income_sigma",
               "1|age_sigma",
               "1|race_eth_sigma",
               "1|edu_sigma",
               "1|household_type_sigma"],
    combined=True,
)
# Out:
# array([<Axes: title={'center': '94.0% HDI'}>], dtype=object)

# %% [markdown]
# ## Percent Rank Debt Model

# %%
pr_debt_model_cols = ['prank_debts',
'state',
'hh_income',
'age',
'race_eth',
'edu',
'tenure',
'household_type',
'male',
'metro',
'disability',
'class_worker',
'public_assistance',
'social_security',
'poverty',
'citizen',
'english_at_home',
'homevalue',
'race_eth_state',	
'race_eth_edu',	
'race_eth_age',	
'race_eth_income']

# %%
pr_debt_model_df = sipp_model.select(pl.col(pr_debt_model_cols)).to_pandas().dropna(subset=pr_debt_model_cols)
pr_debt_model_df
# Out:
#        prank_debts  state  hh_income  age  race_eth  edu  tenure  \
# 1         0.531261     20          8    5         1    3       2
# 3         0.418817     20         10   11         1    2       2
# 7         0.241768     20          8    3         3    4       3
# 8         0.253933     20          6    9         1    4       3
# 9         0.077989     40          2    2         1    2       3
# ...            ...    ...        ...  ...       ...  ...     ...
# 26167     0.471261      6          3    7         4    3       1
# 26168     0.943090      6         13    9         3    1       2
# 26170     0.932720      6         12    7         4    3       2
# 26171     0.015840      6          9    9         4    1       1
# 26172     0.978590      6         14    8         3    2       3
#
#        household_type  male  metro  ...  public_assistance  social_security  \
# 1                   4     0      1  ...                  0                0
# 3                   2     0      1  ...                  0                1
# 7                   2     1      1  ...                  0                0
# 8                   2     1      1  ...                  0                0
# 9                   4     1      0  ...                  0                0
# ...               ...   ...    ...  ...                ...              ...
# 26167               4     0      1  ...                  0                0
# 26168               2     1      1  ...                  0                0
# 26170               1     1      1  ...                  0                1
# 26171               2     1      1  ...                  0                1
# 26172               1     1      1  ...                  1                1
#
#        poverty  citizen  english_at_home  homevalue  race_eth_state  \
# 1            0        1                1          4            1:20
# 3            0        1                1          3            1:20
# 7            0        0                0          1            3:20
# 8            0        1                1          1            1:20
# 9            1        1                1          1            1:40
# ...        ...      ...              ...        ...             ...
# 26167        1        1                1          6             4:6
# 26168        0        1                0          6             3:6
# 26170        0        1                0          6             4:6
# 26171        0        1                0          6             4:6
# 26172        0        1                0          1             3:6
#
#        race_eth_edu race_eth_age race_eth_income
# 1               1:3          1:5             1:8
# 3               1:2         1:11            1:10
# 7               3:4          3:3             3:8
# 8               1:4          1:9             1:6
# 9               1:2          1:2             1:2
# ...             ...          ...             ...
# 26167           4:3          4:7             4:3
# 26168           3:1          3:9            3:13
# 26170           4:3          4:7            4:12
# 26171           4:1          4:9             4:9
# 26172           3:2          3:8            3:14
#
# [17812 rows x 22 columns]

# %%
# since using beta family and min value is 0.000000 squish values to avoid any values that are exactly 0 or 1
eps = 1e-6
pr_debt_model_df["prank_debts_adj"] = np.clip(pr_debt_model_df["prank_debts"], eps, 1 - eps)

# %%
pr_debt_model_df.describe()
# Out:
#         prank_debts         state     hh_income           age      race_eth  \
# count  17812.000000  17812.000000  17812.000000  17812.000000  17812.000000
# mean       0.490756     27.950034     10.321637      7.936896      1.637660
# std        0.286781     16.317810      4.422879      3.207014      1.049541
# min        0.000000      1.000000      1.000000      2.000000      1.000000
# 25%        0.242953     12.000000      7.000000      5.000000      1.000000
# 50%        0.489045     28.000000     10.000000      8.000000      1.000000
# 75%        0.733769     42.000000     14.000000     10.000000      2.000000
# max        0.999936     56.000000     18.000000     15.000000      5.000000
#
#                 edu        tenure  household_type          male         metro  \
# count  17812.000000  17812.000000    17812.000000  17812.000000  17812.000000
# mean       3.074107      2.138165        2.600157      0.490624      0.835616
# std        1.168720      0.685557        1.189201      0.499926      0.370634
# min        1.000000      1.000000        1.000000      0.000000      0.000000
# 25%        2.000000      2.000000        2.000000      0.000000      1.000000
# 50%        3.000000      2.000000        2.000000      0.000000      1.000000
# 75%        4.000000      3.000000        4.000000      1.000000      1.000000
# max        5.000000      3.000000        4.000000      1.000000      1.000000
#
#          disability  class_worker  public_assistance  social_security  \
# count  17812.000000  17812.000000       17812.000000     17812.000000
# mean       0.249439      3.403997           0.056703         0.307321
# std        0.432700      0.950189           0.231281         0.461396
# min        0.000000      1.000000           0.000000         0.000000
# 25%        0.000000      3.000000           0.000000         0.000000
# 50%        0.000000      3.000000           0.000000         0.000000
# 75%        0.000000      4.000000           0.000000         1.000000
# max        1.000000      5.000000           1.000000         1.000000
#
#             poverty       citizen  english_at_home     homevalue  \
# count  17812.000000  17812.000000     17812.000000  17812.000000
# mean       0.113463      0.949753         0.879239      3.234617
# std        0.317167      0.218460         0.325859      1.836421
# min        0.000000      0.000000         0.000000      1.000000
# 25%        0.000000      1.000000         1.000000      1.000000
# 50%        0.000000      1.000000         1.000000      4.000000
# 75%        0.000000      1.000000         1.000000      4.000000
# max        1.000000      1.000000         1.000000      8.000000
#
#        prank_debts_adj
# count     17812.000000
# mean          0.490756
# std           0.286781
# min           0.000001
# 25%           0.242953
# 50%           0.489045
# 75%           0.733769
# max           0.999936

# %%
pr_debt_model_df
# Out:
#        state  hh_income  age  race_eth  edu  tenure  household_type  male  \
# 1         20          8    5         1    3       2               4     0
# 3         20         10   11         1    2       2               2     0
# 7         20          8    3         3    4       3               2     1
# 8         20          6    9         1    4       3               2     1
# 9         40          2    2         1    2       3               4     1
# ...      ...        ...  ...       ...  ...     ...             ...   ...
# 26167      6          3    7         4    3       1               4     0
# 26168      6         13    9         3    1       2               2     1
# 26170      6         12    7         4    3       2               1     1
# 26171      6          9    9         4    1       1               2     1
# 26172      6         14    8         3    2       3               1     1
#
#        metro  disability  ...  social_security  poverty  citizen  \
# 1          1           0  ...                0        0        1
# 3          1           0  ...                1        0        1
# 7          1           0  ...                0        0        0
# 8          1           1  ...                0        0        1
# 9          0           0  ...                0        1        1
# ...      ...         ...  ...              ...      ...      ...
# 26167      1           0  ...                0        1        1
# 26168      1           0  ...                0        0        1
# 26170      1           1  ...                1        0        1
# 26171      1           1  ...                1        0        1
# 26172      1           1  ...                1        0        1
#
#        english_at_home  homevalue  race_eth_state  race_eth_edu race_eth_age  \
# 1                    1          4            1:20           1:3          1:5
# 3                    1          3            1:20           1:2         1:11
# 7                    0          1            3:20           3:4          3:3
# 8                    1          1            1:20           1:4          1:9
# 9                    1          1            1:40           1:2          1:2
# ...                ...        ...             ...           ...          ...
# 26167                1          6             4:6           4:3          4:7
# 26168                0          6             3:6           3:1          3:9
# 26170                0          6             4:6           4:3          4:7
# 26171                0          6             4:6           4:1          4:9
# 26172                0          1             3:6           3:2          3:8
#
#       race_eth_income prank_debts_adj
# 1                 1:8        0.531261
# 3                1:10        0.418817
# 7                 3:8        0.241768
# 8                 1:6        0.253933
# 9                 1:2        0.077989
# ...               ...             ...
# 26167             4:3        0.471261
# 26168            3:13        0.943090
# 26170            4:12        0.932720
# 26171             4:9        0.015840
# 26172            3:14        0.978590
#
# [17812 rows x 22 columns]

# %%
pr_debt_model_df.drop(['prank_debts'],axis=1,inplace=True)

# %%
for col in ['state','hh_income','age','race_eth','edu','tenure',
            'household_type','class_worker','homevalue','race_eth_state',
            'race_eth_edu',	'race_eth_age',	'race_eth_income']:
    pr_debt_model_df[col] = pr_debt_model_df[col].astype('category')

# %%
pr_debt_model_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17812 entries, 1 to 26172
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   state              17812 non-null  category
#  1   hh_income          17812 non-null  category
#  2   age                17812 non-null  category
#  3   race_eth           17812 non-null  category
#  4   edu                17812 non-null  category
#  5   tenure             17812 non-null  category
#  6   household_type     17812 non-null  category
#  7   male               17812 non-null  int32
#  8   metro              17812 non-null  int8
#  9   disability         17812 non-null  int32
#  10  class_worker       17812 non-null  category
#  11  public_assistance  17812 non-null  int8
#  12  social_security    17812 non-null  int8
#  13  poverty            17812 non-null  int8
#  14  citizen            17812 non-null  int32
#  15  english_at_home    17812 non-null  int32
#  16  homevalue          17812 non-null  category
#  17  race_eth_state     17812 non-null  category
#  18  race_eth_edu       17812 non-null  category
#  19  race_eth_age       17812 non-null  category
#  20  race_eth_income    17812 non-null  category
#  21  prank_debts_adj    17812 non-null  float64
# dtypes: category(13), float64(1), int32(4), int8(4)
# memory usage: 890.1 KB

# %%
# change tenure from random effect to fixed effect
pr_debt_model_formula = """
prank_debts_adj ~ male + metro + disability + class_worker + public_assistance
            + social_security + poverty + citizen + english_at_home + homevalue
            + tenure
            + (1|state) + (1|hh_income) + (1|age) + (1|race_eth) + (1|edu)
            + (1|household_type)
            + (1|race_eth:state) + (1|race_eth:edu) + (1|race_eth:age) + (1|race_eth:hh_income)
"""

# %%
pr_debt_priors = {
    "Intercept": bmb.Prior("Normal", mu=0, sigma=2.5),
    "common": bmb.Prior("Normal", mu=0, sigma=1),
    "group_specific": bmb.Prior(
        "Normal",
        mu=0,
        sigma=bmb.Prior("Exponential", lam=1),
    )
}

# %%
pr_debt_model = bmb.Model(formula=pr_debt_model_formula, 
                            data=pr_debt_model_df, 
                            family="beta",
                            link='logit',
                            priors=pr_debt_priors,
                            noncentered=True)

# %%
pr_debt_model_idata = pr_debt_model.fit(draws=2500,
                                          tune=2500,
                                          chains=4,
                                          target_accept=0.99)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [kappa, Intercept, male, metro, disability, class_worker, public_assistance, social_security, poverty, citizen, english_at_home, homevalue, tenure, 1|state_sigma, 1|state_offset, 1|hh_income_sigma, 1|hh_income_offset, 1|age_sigma, 1|age_offset, 1|race_eth_sigma, 1|race_eth_offset, 1|edu_sigma, 1|edu_offset, 1|household_type_sigma, 1|household_type_offset, 1|race_eth:state_sigma, 1|race_eth:state_offset, 1|race_eth:edu_sigma, 1|race_eth:edu_offset, 1|race_eth:age_sigma, 1|race_eth:age_offset, 1|race_eth:hh_income_sigma, 1|race_eth:hh_income_offset]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 2_500 tune and 2_500 draw iterations (10_000 + 10_000 draws total) took 14122 seconds.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.

# %%
az.to_netcdf(pr_debt_model_idata,r'models/pr_debt_model_20260216.nc')
# Out:
# 'models/pr_debt_model_20260216.nc'

# %%
pr_debt_model_summ = az.summary(pr_debt_model_idata, var_names=["Intercept", "male", "metro","disability",'class_worker','public_assistance',
                                                                  'social_security',"poverty","citizen",'english_at_home','homevalue',
                                                                  'tenure'], round_to=3)
pr_debt_model_summ[["mean","sd","hdi_3%","hdi_97%","r_hat","ess_bulk","ess_tail"]]
# Out:
#                     mean     sd  hdi_3%  hdi_97%  r_hat   ess_bulk  ess_tail
# Intercept         -0.300  0.388  -1.026    0.432  1.002   2696.172  4787.894
# male              -0.006  0.014  -0.031    0.020  1.000  26547.212  7225.169
# metro             -0.010  0.019  -0.044    0.026  1.000  23876.368  7279.276
# disability         0.064  0.017   0.031    0.096  1.000  25537.442  7543.152
# class_worker[2.0] -0.319  0.046  -0.409   -0.235  1.000  10865.362  7971.062
# class_worker[3.0] -0.444  0.038  -0.517   -0.373  1.000  10899.585  7660.091
# class_worker[4.0] -0.487  0.049  -0.581   -0.397  1.000  10297.168  8428.069
# class_worker[5.0] -0.389  0.042  -0.464   -0.307  1.000  10844.129  7922.175
# public_assistance -0.041  0.029  -0.097    0.012  1.000  24153.824  7350.440
# social_security   -0.013  0.024  -0.057    0.031  1.001  15878.939  7386.924
# poverty            0.019  0.031  -0.038    0.078  1.000  22550.538  7943.607
# citizen            0.168  0.033   0.106    0.232  1.001  21593.318  6649.694
# english_at_home   -0.001  0.024  -0.045    0.045  1.001  26599.041  7062.660
# homevalue[2]      -0.849  0.351  -1.506   -0.183  1.002   2550.132  4692.024
# homevalue[3]      -0.474  0.350  -1.136    0.175  1.002   2552.547  4437.642
# homevalue[4]      -0.226  0.350  -0.867    0.445  1.002   2553.412  4547.029
# homevalue[5]       0.094  0.350  -0.561    0.756  1.002   2547.041  4528.584
# homevalue[6]       0.326  0.351  -0.321    0.991  1.002   2565.902  4713.093
# homevalue[7]       0.592  0.353  -0.057    1.268  1.002   2613.497  4781.531
# homevalue[8]       0.768  0.352   0.086    1.414  1.002   2604.630  4639.573
# tenure[2]          1.301  0.019   1.265    1.339  1.000  25151.813  7611.530
# tenure[3]         -0.277  0.350  -0.941    0.371  1.002   2541.147  4512.299

# %%
post_vars = list(pr_debt_model_idata.posterior.data_vars)
sd_like = [v for v in post_vars if ("sigma" in v.lower()) or ("sd" in v.lower())]
summ_sd = az.summary(pr_debt_model_idata, var_names=sd_like, round_to=3)
summ_sd
# Out:
#                              mean     sd  hdi_3%  hdi_97%  mcse_mean  mcse_sd  \
# 1|state_sigma               0.029  0.016   0.000    0.054      0.000    0.000
# 1|hh_income_sigma           0.297  0.059   0.198    0.406      0.001    0.001
# 1|age_sigma                 0.137  0.043   0.064    0.217      0.001    0.001
# 1|race_eth_sigma            0.037  0.038   0.000    0.098      0.000    0.001
# 1|edu_sigma                 0.207  0.123   0.062    0.408      0.002    0.004
# 1|household_type_sigma      0.127  0.105   0.031    0.286      0.002    0.006
# 1|race_eth:state_sigma      0.044  0.013   0.019    0.068      0.000    0.000
# 1|race_eth:edu_sigma        0.070  0.020   0.036    0.109      0.000    0.000
# 1|race_eth:age_sigma        0.062  0.017   0.032    0.095      0.000    0.000
# 1|race_eth:hh_income_sigma  0.037  0.018   0.000    0.065      0.000    0.000
#
#                             ess_bulk  ess_tail  r_hat
# 1|state_sigma               1692.011  4145.147  1.000
# 1|hh_income_sigma           3332.806  5303.804  1.001
# 1|age_sigma                 4113.172  4694.900  1.001
# 1|race_eth_sigma            6039.463  7046.009  1.000
# 1|edu_sigma                 5569.157  6095.950  1.001
# 1|household_type_sigma      6204.609  5943.527  1.000
# 1|race_eth:state_sigma      1989.222  2232.487  1.002
# 1|race_eth:edu_sigma        4708.753  7080.204  1.000
# 1|race_eth:age_sigma        3419.124  5707.610  1.000
# 1|race_eth:hh_income_sigma  2434.768  3395.436  1.001

# %%
az.plot_trace(
    pr_debt_model_idata,
    var_names=["Intercept", "male", "metro", "1|hh_income_sigma"],
)
# Out:
# array([[<Axes: title={'center': 'Intercept'}>,
#         <Axes: title={'center': 'Intercept'}>],
#        [<Axes: title={'center': 'male'}>,
#         <Axes: title={'center': 'male'}>],
#        [<Axes: title={'center': 'metro'}>,
#         <Axes: title={'center': 'metro'}>],
#        [<Axes: title={'center': '1|hh_income_sigma'}>,
#         <Axes: title={'center': '1|hh_income_sigma'}>]], dtype=object)

# %%
az.plot_posterior(
    pr_debt_model_idata,
    var_names=["metro", "male", "citizen"],
    hdi_prob=0.95
)
# Out:
# array([<Axes: title={'center': 'metro'}>,
#        <Axes: title={'center': 'male'}>,
#        <Axes: title={'center': 'citizen'}>], dtype=object)

# %%
az.plot_forest(
    pr_debt_model_idata,
    var_names=["1|state_sigma",
               "1|hh_income_sigma",
               "1|age_sigma",
               "1|race_eth_sigma",
               "1|edu_sigma",
               "1|household_type_sigma"],
    combined=True,
)
# Out:
# array([<Axes: title={'center': '94.0% HDI'}>], dtype=object)
